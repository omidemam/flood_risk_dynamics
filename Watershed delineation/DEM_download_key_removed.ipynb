# %% [markdown]
# #### This notebook downloads DEM for each HUC12, and plots them
# ##### Author: Omid Emamjomehzadeh (https://www.omidemam.com/)
# ##### Supervisor: Dr. Omar Wani (https://engineering.nyu.edu/faculty/omar-wani)
# ##### Hydrologic Systems Group @NYU (https://www.omarwani.com/)

# %%
# Import libraries
import numpy as np
import geopandas as gpd
import os
import time
import requests
import time
import rasterio
from osgeo import gdal
from rasterio.mask import mask
from rasterio.warp import calculate_default_transform, reproject, Resampling
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
from matplotlib.patches import Patch
from matplotlib_scalebar.scalebar import ScaleBar
import contextily as ctx
from watermark import watermark
from pyproj import CRS
from pathlib import Path
import datetime

# %% [markdown]
# # 1-m DEM dateset
# United States Geological Survey (2021). United States Geological Survey 3D Elevation Program 1 meter Digital Elevation Model. Distributed by OpenTopography. https://doi.org/10.5069/G98K778D. Accessed: 2025-01-30

# %% [markdown]
# # Dataset avialability in NYS

# %%
# Load USGS 1m Raster Coverage GeoJSON
url = "https://raw.githubusercontent.com/OpenTopography/Data_Catalog_Spatial_Boundaries/main/OpenTopography_Raster/USGS1m.geojson"
gdf = gpd.read_file(url)

# Load NYS shapefile
base_dir = r'D:\culvert repo\data\initial layers'
state_shapefile_path = rf"{base_dir}\state_5070.shp"

# Read and reproject NYS shapefile
state_shapefile = gpd.read_file(state_shapefile_path).to_crs(epsg=3857)

# Reproject USGS raster dataset to match NYS (EPSG:3857 for compatibility with contextily)
gdf = gdf.to_crs(epsg=3857)

# Clip the USGS 1m data to the NYS boundary
gdf_ny = gpd.overlay(gdf, state_shapefile, how="intersection")

# Plot
fig, ax = plt.subplots(figsize=(8, 8))

# Plot the New York State boundary
state_shapefile.plot(ax=ax, facecolor="none", edgecolor="black", linewidth=2, linestyle="-", label="NYS Boundary")

# Plot the clipped USGS 1m raster coverage with hatching
gdf_ny.plot(ax=ax, facecolor="none", edgecolor="red", linewidth=1, linestyle="--", hatch='xx',alpha=0.5, label="USGS 1m Coverage")

# Add basemap
ctx.add_basemap(ax, source=ctx.providers.CartoDB.Positron, crs=gdf_ny.crs)

# Set title
ax.set_title("USGS 1m DEM Availability - New York State", fontsize=15)

# Adjust plot limits to match NYS extent
ax.set_xlim(state_shapefile.total_bounds[0], state_shapefile.total_bounds[2])
ax.set_ylim(state_shapefile.total_bounds[1], state_shapefile.total_bounds[3])

# Axis labels 
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')

# Custom legend
legend_elements = [
    Line2D([0], [0], color='black', lw=2, linestyle="-", label="NYS Boundary"),
    Patch(facecolor='none', edgecolor='red', linestyle='--', hatch='xx', alpha=0.5, label="USGS 1m Raster Coverage")
]
ax.legend(handles=legend_elements, loc="upper left")

plt.savefig(r'D:\culvert repo\Results\Figures\USGS_1m_DEM_Coverage_NYS.png', dpi=300)
plt.show()

# %% [markdown]
# # Download and save the DEM for each HUC12

# %%
# %%time 
base_dir=r'D:\culvert repo\Results\Clipped_layers'
#Define layers directories
output_huc12_dir = rf'{base_dir}\clipped_huc12'
output_DEM_dir=rf'{base_dir}\HUC12_one meter_DEM'

# Set the flags
fileone= False
filetwo= False
reproout= False
output_mosaic_flag=False

# Read HUC12 list
file_path = r"D:\culvert repo\Results\Lists\huc12_with_all_layers.txt"
with open(file_path, 'r') as file:
    huc12_with_all_layers = [line.strip() for line in file]
total_hucs=len(huc12_with_all_layers)    
#########################################################################################################################################################
for i, huc in enumerate(huc12_with_all_layers):
    clipped_tiff = fr'{base_dir}\HUC12_one meter_DEM\{huc}\{huc}_DEM.tiff'

    # Check if the file exists; if so, skip to the next iteration
    if os.path.exists(clipped_tiff):
        print(f"File {clipped_tiff} already exists. Skipping...")
        continue
    
    try:
        print(huc)
        # Print the HUC number and the percent of remaining HUCs in this chunk
        remaining_files = total_hucs - (i + 1)
        percent_remaining = (remaining_files / total_hucs) * 100
        print(f"HUC number: {huc}, Percent of remaining files: {percent_remaining:.2f}%")
        # path to the specific HUC layer
        output_huc12_path = os.path.join(output_huc12_dir, f'{huc}_huc12.shp')
        huc12 = gpd.read_file(output_huc12_path)
#########################################################################################################################################################
        # Define a bounding box over the HUC
        huc12 = huc12.to_crs(epsg=4326)
        minx, miny, maxx, maxy = huc12.bounds['minx'][0], huc12.bounds['miny'][0], huc12.bounds['maxx'][0], huc12.bounds['maxy'][0]
        # API call
        url = 'https://portal.opentopography.org/API/usgsdem'
        params = {
            'datasetName': 'USGS1m',
            'south': miny,
            'north': maxy,
            'west': minx,
            'east': maxx,
            'outputFormat': 'GTiff',
            #'API_Key': enter the API key from opentopography
        }
        headers = {
            'accept': '*/*'
        }
        
        # Directory to save the downloaded DEMs
        output_DEM_dir = fr'{base_dir}\HUC12_one meter_DEM\{huc}'
        if not os.path.exists(output_DEM_dir):
            os.makedirs(output_DEM_dir)
        
        # Function to download DEM
        def download_dem(west, east, filename):
            for attempt in range(3):
                params.update({'south': miny, 'north': maxy, 'west': west, 'east': east})
                response = requests.get(url, params=params, headers=headers)
                
                if response.status_code == 200:
                    file_path = f'{output_DEM_dir}/{filename}.tiff'
                    with open(file_path, 'wb') as f:
                        f.write(response.content)
                    print(f'File {filename} downloaded successfully and saved to {file_path}.')
                    return file_path
                elif response.status_code == 400:
                    print(f"400 Bad Request for {filename}. Splitting the bounding box and retrying.")
                    return None
                else:
                    print(f"Attempt {attempt + 1}: Failed to retrieve data - Status code: {response.status_code}")
                    if attempt < 2:
                        time.sleep(5)  # Wait for 5 seconds before retrying
                    else:
                        print(f"Failed to download {filename} after 3 attempts.")
                        return None
        
        # First attempt to download the DEM
        file_path = download_dem(minx, maxx, f'{huc}')
        
        # If 400 error occurs, download two DEMs by splitting the bounding box
        if file_path is None:
            midx = (minx + maxx) / 2
            file1 = download_dem(minx, midx+((maxx-minx)*0.1), f'{huc}_west')
            fileone= True
            file2 = download_dem(midx-((maxx-minx)*0.1), maxx, f'{huc}_east')
            filetwo= True
            with rasterio.open(file1) as src1, rasterio.open(file2) as src2:
                # Check if both files were downloaded successfully
                if file1 and file2:
    
                    input_files = [file1, file2]
                    
                    # Define output file paths
                    output_mosaic = fr"{base_dir}\HUC12_one meter_DEM\{huc}\{huc}_east_west_mosaic.tiff"
                    reprojected_output = fr"{base_dir}\HUC12_one meter_DEM\{huc}\{huc}_mosaic_reprojected.tiff"

                    # Mosaic the input files
                    vrt_options = gdal.BuildVRTOptions(resampleAlg='nearest')
                    mosaic_vrt = gdal.BuildVRT('mosaic.vrt', input_files, options=vrt_options)

                    # Check if the VRT was created successfully
                    if mosaic_vrt is None:
                        raise ValueError("Failed to create the VRT mosaic.")
                        
                    # Convert the VRT to a GeoTIFF
                    translated = gdal.Translate(output_mosaic, mosaic_vrt)
                    output_mosaic_flag = True
                    if translated is None:
                        raise ValueError("Failed to translate the VRT to a GeoTIFF.")
                    # Reproject the mosaic to the target CRS (NAD_1983_UTM)
                    target_crs = 'EPSG:4326'  # Replace with the correct EPSG code for your UTM zone
                    warp_options = gdal.WarpOptions(dstSRS=target_crs)
                    warped = gdal.Warp(reprojected_output, output_mosaic, options=warp_options)
                    file_path=reprojected_output
                    reproout= True
                    #close
                    warped= None
                    mosaic_vrt=None  
                    translated=None
                else:
                    print("Failed to download one or both of the DEMs, cannot proceed with mosaicing.")
            src1.close()
            src2.close()
#########################################################################################################################################################
        #reproject the temporary tiff from 4326 to 5070
        output_tiff=fr'{base_dir}\HUC12_one meter_DEM\{huc}\{huc}_5070.tiff'
        
        # Define source and target CRS
        src_crs = CRS.from_epsg(4326)  # Original CRS (EPSG:4326)
        dst_crs = CRS.from_epsg(5070)  # Target CRS (EPSG:5070)
        
        # Open the source raster
        with rasterio.open(file_path) as src:
            transform, width, height = calculate_default_transform(
                src.crs, dst_crs, src.width, src.height, *src.bounds)
            kwargs = src.meta.copy()
            kwargs.update({
                'crs': dst_crs,
                'transform': transform,
                'width': width,
                'height': height
            })
        
            # Reproject and save to the output file
            with rasterio.open(output_tiff, 'w', **kwargs) as dst:
                for i in range(1, src.count + 1):
                    reproject(
                        source=rasterio.band(src, i),
                        destination=rasterio.band(dst, i),
                        src_transform=src.transform,
                        src_crs=src.crs,
                        dst_transform=transform,
                        dst_crs=dst_crs,
                        resampling=Resampling.nearest
                    )
#########################################################################################################################################################
        # Clip and save the final reprojected DEM
        clipped_tiff_dir = fr'{base_dir}\HUC12_one meter_DEM\{huc}'
        huc12 = huc12.to_crs(epsg=5070)
        # Path file
        clipped_tiff = os.path.join(clipped_tiff_dir, f'{huc}_DEM.tiff')
    
        # Convert the HUC12 boundary to GeoJSON-like format
        huc12_geom = [feature["geometry"] for feature in huc12.__geo_interface__["features"]]
    
        # Open the reprojected TIFF file and clip it using the HUC12 boundary
        with rasterio.open(output_tiff) as src:
            out_image, out_transform = mask(src, huc12_geom, crop=True)
            out_image[out_image == src.nodata] = -99999  # Set NoData value
            out_meta = src.meta.copy()
            out_meta.update({
                "driver": "GTiff",
                "height": out_image.shape[1],
                "width": out_image.shape[2],
                "transform": out_transform,
                "crs": src.crs,
                "nodata": -99999
            })
    
            # Save the clipped DEM to a new file
            with rasterio.open(clipped_tiff, 'w', **out_meta) as dst:
                dst.write(out_image)
        src.close()
#########################################################################################################################################################
        #Remove other files
        if fileone: 
            fileone= False
            try:
                os.remove(file1)
                print(f"{file1} removed successfully.")
            except FileNotFoundError:
                print(f"{file1} does not exist.") 
                
        if filetwo: 
            filetwo= False
            try:
                os.remove(file2)
                print(f"{file2} removed successfully.")
            except FileNotFoundError:
                print(f"{file2} does not exist.")   
            del file2
                
        file=f'{output_DEM_dir}\\{huc}.tiff'
        if  os.path.exists(file):
            try:
                os.remove(file)
                print(f"{file} removed successfully.")
            except FileNotFoundError:
                print(f"{file} does not exist.")  
            del file
        
     
        try:
            os.remove(output_tiff)
            print(f"{output_tiff} removed successfully.")
        except FileNotFoundError:
            print(f"{output_tiff} does not exist.")  
            del output_tiff

        
        if reproout:
            reproout=False
            try:
                os.remove(reprojected_output)
                print(f"{reprojected_output} removed successfully.")
            except FileNotFoundError:
                print(f"{reprojected_output} does not exist.")  
            del reprojected_output

        if output_mosaic_flag:
            output_mosaic_flag=False
            try:
                os.remove(output_mosaic)
                print(f"{output_mosaic} removed successfully.")
            except FileNotFoundError:
                print(f"{output_mosaic} does not exist.")  
            del output_mosaic
#########################################################################################################################################################
    except Exception as e:
        print(f"Failed to analyse HUC {huc}. Error: {e}")
# Out:
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\050100020104\050100020104_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041201010101\041201010101_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020302020202\020302020202_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020302020205\020302020205_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020302020207\020302020207_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020302020303\020302020303_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020302020304\020302020304_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020302020402\020302020402_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020302020406\020302020406_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020302020605\020302020605_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\011000060401\011000060401_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\011000060402\011000060402_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\011000050501\011000050501_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\011000060403\011000060403_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\011000050504\011000050504_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020301040201\020301040201_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020301040204\020301040204_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020301020203\020301020203_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020301010302\020301010302_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020301020201\020301020201_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020302010201\020302010201_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020302010202\020302010202_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020302010203\020302010203_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020302010302\020302010302_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020301040501\020301040501_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\050100020404\050100020404_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\050100020407\050100020407_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\050100020503\050100020503_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\050100011102\050100011102_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\050100011202\050100011202_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\050100011204\050100011204_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\050100040101\050100040101_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\050100040303\050100040303_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\050100010705\050100010705_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\050100011002\050100011002_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\050100010805\050100010805_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\050100010605\050100010605_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\050100010501\050100010501_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\050100010403\050100010403_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\050100010405\050100010405_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\050100040301\050100040301_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\050100010205\050100010205_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\050100010207\050100010207_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\050100020105\050100020105_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\050100010505\050100010505_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\050100010504\050100010504_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\050100020102\050100020102_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\050100010703\050100010703_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\050100020206\050100020206_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\050100020203\050100020203_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\050100020207\050100020207_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\050100020303\050100020303_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\050100020401\050100020401_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401020104\020401020104_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401010301\020401010301_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401010304\020401010304_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401020306\020401020306_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401020403\020401020403_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401020405\020401020405_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401020506\020401020506_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401040102\020401040102_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401040104\020401040104_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401040201\020401040201_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401040303\020401040303_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401040305\020401040305_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401040307\020401040307_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401010207\020401010207_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401040308\020401040308_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401010305\020401010305_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401040504\020401040504_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401010102\020401010102_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401010106\020401010106_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401010103\020401010103_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401010104\020401010104_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401010105\020401010105_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401010201\020401010201_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401010202\020401010202_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401010204\020401010204_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200040311\020200040311_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200040704\020200040704_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200040706\020200040706_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200040901\020200040901_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200041004\020200041004_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200041005\020200041005_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200041106\020200041106_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200041107\020200041107_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200030102\020200030102_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200030206\020200030206_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200070603\020200070603_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200070604\020200070604_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200070605\020200070605_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200080106\020200080106_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200040906\020200040906_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200040907\020200040907_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200040908\020200040908_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200050205\020200050205_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200030704\020200030704_DEM.tiff already exists. Skipping...
# 020200050403
# HUC number: 020200050403, Percent of remaining files: 92.06%
# Attempt 1: Failed to retrieve data - Status code: 204
# Attempt 2: Failed to retrieve data - Status code: 204
# Attempt 3: Failed to retrieve data - Status code: 204
# Failed to download 020200050403 after 3 attempts.
# Attempt 1: Failed to retrieve data - Status code: 204
# Attempt 2: Failed to retrieve data - Status code: 204
# Attempt 3: Failed to retrieve data - Status code: 204
# Failed to download 020200050403_west after 3 attempts.
# Attempt 1: Failed to retrieve data - Status code: 204
# Attempt 2: Failed to retrieve data - Status code: 204
# Attempt 3: Failed to retrieve data - Status code: 204
# Failed to download 020200050403_east after 3 attempts.
# Failed to analyse HUC 020200050403. Error: invalid path or file: None
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200030804\020200030804_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200060402\020200060402_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200050503\020200050503_DEM.tiff already exists. Skipping...
# 020200050604
# HUC number: 020200050604, Percent of remaining files: 91.73%
# Attempt 1: Failed to retrieve data - Status code: 204
# Attempt 2: Failed to retrieve data - Status code: 204
# Attempt 3: Failed to retrieve data - Status code: 204
# Failed to download 020200050604 after 3 attempts.
# Attempt 1: Failed to retrieve data - Status code: 204
# Attempt 2: Failed to retrieve data - Status code: 204
# Attempt 3: Failed to retrieve data - Status code: 204
# Failed to download 020200050604_west after 3 attempts.
# Attempt 1: Failed to retrieve data - Status code: 204
# Attempt 2: Failed to retrieve data - Status code: 204
# Attempt 3: Failed to retrieve data - Status code: 204
# Failed to download 020200050604_east after 3 attempts.
# Failed to analyse HUC 020200050604. Error: invalid path or file: None
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200060204\020200060204_DEM.tiff already exists. Skipping...
# 020200060403
# HUC number: 020200060403, Percent of remaining files: 91.57%
# 400 Bad Request for 020200060403. Splitting the bounding box and retrying.
# 400 Bad Request for 020200060403_west. Splitting the bounding box and retrying.
# 400 Bad Request for 020200060403_east. Splitting the bounding box and retrying.
# Failed to analyse HUC 020200060403. Error: invalid path or file: None
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200060505\020200060505_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200060703\020200060703_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200060802\020200060802_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200020302\020200020302_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200061105\020200061105_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200070303\020200070303_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200070304\020200070304_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200060905\020200060905_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200070301\020200070301_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200070302\020200070302_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200070404\020200070404_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200070502\020200070502_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200070503\020200070503_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200080301\020200080301_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200080404\020200080404_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200080504\020200080504_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200061002\020200061002_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200070201\020200070201_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200070202\020200070202_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200020103\020200020103_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200020202\020200020202_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200020203\020200020203_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200020301\020200020301_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200020304\020200020304_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200020305\020200020305_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200020307\020200020307_DEM.tiff already exists. Skipping...
# 020200020602
# HUC number: 020200020602, Percent of remaining files: 89.38%
# 400 Bad Request for 020200020602. Splitting the bounding box and retrying.
# 400 Bad Request for 020200020602_west. Splitting the bounding box and retrying.
# 400 Bad Request for 020200020602_east. Splitting the bounding box and retrying.
# Failed to analyse HUC 020200020602. Error: invalid path or file: None
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200020606\020200020606_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200020605\020200020605_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200030401\020200030401_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200030403\020200030403_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200030406\020200030406_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200030503\020200030503_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200031104\020200031104_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200040301\020200040301_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200040101\020200040101_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200040105\020200040105_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200040303\020200040303_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200040304\020200040304_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200040305\020200040305_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200040306\020200040306_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200040307\020200040307_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\050100010406\050100010406_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041300020601\041300020601_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041300020903\041300020903_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041300030302\041300030302_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041401010701\041401010701_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020501010603\020501010603_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020501020106\020501020106_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020501010906\020501010906_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020501020104\020501020104_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020501020202\020501020202_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020501040910\020501040910_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041401010102\041401010102_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041201020101\041201020101_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041401010502\041401010502_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041401010602\041401010602_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041401010603\041401010603_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041401010604\041401010604_DEM.tiff already exists. Skipping...
# 020200010702
# HUC number: 020200010702, Percent of remaining files: 86.71%
# Attempt 1: Failed to retrieve data - Status code: 204
# Attempt 2: Failed to retrieve data - Status code: 204
# Attempt 3: Failed to retrieve data - Status code: 204
# Failed to download 020200010702 after 3 attempts.
# Attempt 1: Failed to retrieve data - Status code: 204
# Attempt 2: Failed to retrieve data - Status code: 204
# Attempt 3: Failed to retrieve data - Status code: 204
# Failed to download 020200010702_west after 3 attempts.
# Attempt 1: Failed to retrieve data - Status code: 204
# Attempt 2: Failed to retrieve data - Status code: 204
# Attempt 3: Failed to retrieve data - Status code: 204
# Failed to download 020200010702_east after 3 attempts.
# Failed to analyse HUC 020200010702. Error: invalid path or file: None
# 020200010608
# HUC number: 020200010608, Percent of remaining files: 86.63%
# Attempt 1: Failed to retrieve data - Status code: 204
# Attempt 2: Failed to retrieve data - Status code: 204
# Attempt 3: Failed to retrieve data - Status code: 204
# Failed to download 020200010608 after 3 attempts.
# Attempt 1: Failed to retrieve data - Status code: 204
# Attempt 2: Failed to retrieve data - Status code: 204
# Attempt 3: Failed to retrieve data - Status code: 204
# Failed to download 020200010608_west after 3 attempts.
# Attempt 1: Failed to retrieve data - Status code: 204
# Attempt 2: Failed to retrieve data - Status code: 204
# Attempt 3: Failed to retrieve data - Status code: 204
# Failed to download 020200010608_east after 3 attempts.
# Failed to analyse HUC 020200010608. Error: invalid path or file: None
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200010705\020200010705_DEM.tiff already exists. Skipping...
# 020200010201
# HUC number: 020200010201, Percent of remaining files: 86.47%
# 400 Bad Request for 020200010201. Splitting the bounding box and retrying.
# 400 Bad Request for 020200010201_west. Splitting the bounding box and retrying.
# 400 Bad Request for 020200010201_east. Splitting the bounding box and retrying.
# Failed to analyse HUC 020200010201. Error: invalid path or file: None
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200010202\020200010202_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200010203\020200010203_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200010103\020200010103_DEM.tiff already exists. Skipping...
# 020200010105
# HUC number: 020200010105, Percent of remaining files: 86.14%
# Attempt 1: Failed to retrieve data - Status code: 204
# Attempt 2: Failed to retrieve data - Status code: 204
# Attempt 3: Failed to retrieve data - Status code: 204
# Failed to download 020200010105 after 3 attempts.
# Attempt 1: Failed to retrieve data - Status code: 204
# Attempt 2: Failed to retrieve data - Status code: 204
# Attempt 3: Failed to retrieve data - Status code: 204
# Failed to download 020200010105_west after 3 attempts.
# Attempt 1: Failed to retrieve data - Status code: 204
# Attempt 2: Failed to retrieve data - Status code: 204
# Attempt 3: Failed to retrieve data - Status code: 204
# Failed to download 020200010105_east after 3 attempts.
# Failed to analyse HUC 020200010105. Error: invalid path or file: None
# 020200010107
# HUC number: 020200010107, Percent of remaining files: 86.06%
# Attempt 1: Failed to retrieve data - Status code: 204
# Attempt 2: Failed to retrieve data - Status code: 204
# Attempt 3: Failed to retrieve data - Status code: 204
# Failed to download 020200010107 after 3 attempts.
# Attempt 1: Failed to retrieve data - Status code: 204
# Attempt 2: Failed to retrieve data - Status code: 204
# Attempt 3: Failed to retrieve data - Status code: 204
# Failed to download 020200010107_west after 3 attempts.
# Attempt 1: Failed to retrieve data - Status code: 204
# Attempt 2: Failed to retrieve data - Status code: 204
# Attempt 3: Failed to retrieve data - Status code: 204
# Failed to download 020200010107_east after 3 attempts.
# Failed to analyse HUC 020200010107. Error: invalid path or file: None
# 020200010205
# HUC number: 020200010205, Percent of remaining files: 85.98%
# 400 Bad Request for 020200010205. Splitting the bounding box and retrying.
# 400 Bad Request for 020200010205_west. Splitting the bounding box and retrying.
# 400 Bad Request for 020200010205_east. Splitting the bounding box and retrying.
# Failed to analyse HUC 020200010205. Error: invalid path or file: None
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200010301\020200010301_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200010304\020200010304_DEM.tiff already exists. Skipping...
# 020200010402
# HUC number: 020200010402, Percent of remaining files: 85.74%
# Attempt 1: Failed to retrieve data - Status code: 204
# Attempt 2: Failed to retrieve data - Status code: 204
# Attempt 3: Failed to retrieve data - Status code: 204
# Failed to download 020200010402 after 3 attempts.
# Attempt 1: Failed to retrieve data - Status code: 204
# Attempt 2: Failed to retrieve data - Status code: 204
# Attempt 3: Failed to retrieve data - Status code: 204
# Failed to download 020200010402_west after 3 attempts.
# Attempt 1: Failed to retrieve data - Status code: 204
# Attempt 2: Failed to retrieve data - Status code: 204
# Attempt 3: Failed to retrieve data - Status code: 204
# Failed to download 020200010402_east after 3 attempts.
# Failed to analyse HUC 020200010402. Error: invalid path or file: None
# 020200010407
# HUC number: 020200010407, Percent of remaining files: 85.66%
# Attempt 1: Failed to retrieve data - Status code: 204
# Attempt 2: Failed to retrieve data - Status code: 204
# Attempt 3: Failed to retrieve data - Status code: 204
# Failed to download 020200010407 after 3 attempts.
# Attempt 1: Failed to retrieve data - Status code: 204
# Attempt 2: Failed to retrieve data - Status code: 204
# Attempt 3: Failed to retrieve data - Status code: 204
# Failed to download 020200010407_west after 3 attempts.
# Attempt 1: Failed to retrieve data - Status code: 204
# Attempt 2: Failed to retrieve data - Status code: 204
# Attempt 3: Failed to retrieve data - Status code: 204
# Failed to download 020200010407_east after 3 attempts.
# Failed to analyse HUC 020200010407. Error: invalid path or file: None
# 020200010408
# HUC number: 020200010408, Percent of remaining files: 85.58%
# Attempt 1: Failed to retrieve data - Status code: 204
# Attempt 2: Failed to retrieve data - Status code: 204
# Attempt 3: Failed to retrieve data - Status code: 204
# Failed to download 020200010408 after 3 attempts.
# Attempt 1: Failed to retrieve data - Status code: 204
# Attempt 2: Failed to retrieve data - Status code: 204
# Attempt 3: Failed to retrieve data - Status code: 204
# Failed to download 020200010408_west after 3 attempts.
# Attempt 1: Failed to retrieve data - Status code: 204
# Attempt 2: Failed to retrieve data - Status code: 204
# Attempt 3: Failed to retrieve data - Status code: 204
# Failed to download 020200010408_east after 3 attempts.
# Failed to analyse HUC 020200010408. Error: invalid path or file: None
# 020200010403
# HUC number: 020200010403, Percent of remaining files: 85.49%
# Attempt 1: Failed to retrieve data - Status code: 204
# Attempt 2: Failed to retrieve data - Status code: 204
# Attempt 3: Failed to retrieve data - Status code: 204
# Failed to download 020200010403 after 3 attempts.
# Attempt 1: Failed to retrieve data - Status code: 204
# Attempt 2: Failed to retrieve data - Status code: 204
# Attempt 3: Failed to retrieve data - Status code: 204
# Failed to download 020200010403_west after 3 attempts.
# Attempt 1: Failed to retrieve data - Status code: 204
# Attempt 2: Failed to retrieve data - Status code: 204
# Attempt 3: Failed to retrieve data - Status code: 204
# Failed to download 020200010403_east after 3 attempts.
# Failed to analyse HUC 020200010403. Error: invalid path or file: None
# 020200010405
# HUC number: 020200010405, Percent of remaining files: 85.41%
# 400 Bad Request for 020200010405. Splitting the bounding box and retrying.
# File 020200010405_west downloaded successfully and saved to D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200010405/020200010405_west.tiff.
# Attempt 1: Failed to retrieve data - Status code: 204
# Attempt 2: Failed to retrieve data - Status code: 204
# Attempt 3: Failed to retrieve data - Status code: 204
# Failed to download 020200010405_east after 3 attempts.
# Failed to analyse HUC 020200010405. Error: invalid path or file: None
# 020200010406
# HUC number: 020200010406, Percent of remaining files: 85.33%
# Attempt 1: Failed to retrieve data - Status code: 204
# Attempt 2: Failed to retrieve data - Status code: 204
# Attempt 3: Failed to retrieve data - Status code: 204
# Failed to download 020200
_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402020802\041402020802_DEM.tiff already exists. Skipping...
# 041402020807
# HUC number: 041402020807, Percent of remaining files: 7.21%
# 400 Bad Request for 041402020807. Splitting the bounding box and retrying.
# 400 Bad Request for 041402020807_west. Splitting the bounding box and retrying.
# 400 Bad Request for 041402020807_east. Splitting the bounding box and retrying.
# Failed to analyse HUC 041402020807. Error: invalid path or file: None
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402020905\041402020905_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402020805\041402020805_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402020806\041402020806_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402020902\041402020902_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402020903\041402020903_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402030102\041402030102_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402030103\041402030103_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402030201\041402030201_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402030204\041402030204_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401010306\020401010306_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401010503\020401010503_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401010504\020401010504_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401010505\020401010505_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401010603\020401010603_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401020101\020401020101_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401020204\020401020204_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401020302\020401020302_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401020303\020401020303_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401020304\020401020304_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401020305\020401020305_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401020402\020401020402_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401020501\020401020501_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401020502\020401020502_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401020503\020401020503_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401040101\020401040101_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401020505\020401020505_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401020507\020401020507_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401040103\020401040103_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401040105\020401040105_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401040106\020401040106_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401040107\020401040107_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401040202\020401040202_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401040203\020401040203_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401040304\020401040304_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020501010102\020501010102_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020501010103\020501010103_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020501010201\020501010201_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402010903\041402010903_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402010904\041402010904_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402011002\041402011002_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402010905\041402010905_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402010906\041402010906_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402011001\041402011001_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402011004\041402011004_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402011005\041402011005_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402011006\041402011006_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402011007\041402011007_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020501010202\020501010202_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\011000050503\011000050503_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\011000050201\011000050201_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\011000050202\011000050202_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\011000050505\011000050505_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200060601\020200060601_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200060603\020200060603_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200040705\020200040705_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402020402\041402020402_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200040202\020200040202_DEM.tiff already exists. Skipping...
# 020200010607
# HUC number: 020200010607, Percent of remaining files: 2.51%
# Attempt 1: Failed to retrieve data - Status code: 204
# Attempt 2: Failed to retrieve data - Status code: 204
# Attempt 3: Failed to retrieve data - Status code: 204
# Failed to download 020200010607 after 3 attempts.
# Attempt 1: Failed to retrieve data - Status code: 204
# Attempt 2: Failed to retrieve data - Status code: 204
# Attempt 3: Failed to retrieve data - Status code: 204
# Failed to download 020200010607_west after 3 attempts.
# Attempt 1: Failed to retrieve data - Status code: 204
# Attempt 2: Failed to retrieve data - Status code: 204
# Attempt 3: Failed to retrieve data - Status code: 204
# Failed to download 020200010607_east after 3 attempts.
# Failed to analyse HUC 020200010607. Error: invalid path or file: None
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020501011205\020501011205_DEM.tiff already exists. Skipping...
# 043001080203
# HUC number: 043001080203, Percent of remaining files: 2.35%
# Attempt 1: Failed to retrieve data - Status code: 204
# Attempt 2: Failed to retrieve data - Status code: 204
# Attempt 3: Failed to retrieve data - Status code: 204
# Failed to download 043001080203 after 3 attempts.
# Attempt 1: Failed to retrieve data - Status code: 204
# Attempt 2: Failed to retrieve data - Status code: 204
# Attempt 3: Failed to retrieve data - Status code: 204
# Failed to download 043001080203_west after 3 attempts.
# Attempt 1: Failed to retrieve data - Status code: 204
# Attempt 2: Failed to retrieve data - Status code: 204
# Attempt 3: Failed to retrieve data - Status code: 204
# Failed to download 043001080203_east after 3 attempts.
# Failed to analyse HUC 043001080203. Error: invalid path or file: None
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200080203\020200080203_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020501020102\020501020102_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402020904\041402020904_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020501020103\020501020103_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\011000050506\011000050506_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020301010105\020301010105_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020501010401\020501010401_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020501011206\020501011206_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020501020301\020501020301_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401010206\020401010206_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200040308\020200040308_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020501011104\020501011104_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020501010101\020501010101_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200040902\020200040902_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402020604\041402020604_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401010205\020401010205_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401010302\020401010302_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402020601\041402020601_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401010303\020401010303_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020501010902\020501010902_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020501020501\020501020501_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401010101\020401010101_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200080505\020200080505_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402020701\041402020701_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020501010601\020501010601_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200040204\020200040204_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200061001\020200061001_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\011000060405\011000060405_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020301020202\020301020202_DEM.tiff already exists. Skipping...
# CPU times: total: 4.19 s
# Wall time: 15min 22s

# %%
# Report percent of HUC12s with 1-meter DEM
onemeterdem_count=0
for i, huc in enumerate(huc12_with_all_layers):
    clipped_tiff = fr'{base_dir}\HUC12_one meter_DEM\{huc}\{huc}_DEM.tiff'
    if os.path.exists(clipped_tiff):
        onemeterdem_count+=1
        continue
print(f'Percent of huc12s with 1-meter dem is {onemeterdem_count/len(huc12_with_all_layers)* 100:.2f}  %')
# Out:
# Percent of huc12s with 1-meter dem is 95.71  %

# %% [markdown]
# #### If the 1-meter dem is not available then download 10-m DEM

# %%
# %%time 
base_dir=r'D:\culvert repo\Results\Clipped_layers'
#Define layers directories
output_huc12_dir = rf'{base_dir}\clipped_huc12'
output_DEM_dir=rf'{base_dir}\HUC12_one meter_DEM'

# SET THE FLAGS
fileone= False
filetwo= False
reproout= False
output_mosaic_flag=False

# Read HUC12 list
file_path = r"D:\culvert repo\Results\Lists\huc12_with_all_layers.txt"
with open(file_path, 'r') as file:
    huc12_with_all_layers = [line.strip() for line in file]
total_hucs=len(huc12_with_all_layers)    
#########################################################################################################################################################
for i, huc in enumerate(huc12_with_all_layers):
    clipped_tiff = fr'{base_dir}\HUC12_one meter_DEM\{huc}\{huc}_DEM.tiff'

    # Check if the file exists; if so, skip to the next iteration
    if os.path.exists(clipped_tiff):
        print(f"File {clipped_tiff} already exists. Skipping...")
        continue
    
    try:
        print(huc)
        # Print the HUC number and the percent of remaining HUCs in this chunk
        remaining_files = total_hucs - (i + 1)
        percent_remaining = (remaining_files / total_hucs) * 100
        print(f"HUC number: {huc}, Percent of remaining files: {percent_remaining:.2f}%")
        # path to the specific HUC layer
        output_huc12_path = os.path.join(output_huc12_dir, f'{huc}_huc12.shp')
        huc12 = gpd.read_file(output_huc12_path)
#########################################################################################################################################################
        # Define a bounding box over the HUC
        huc12 = huc12.to_crs(epsg=4326)
        minx, miny, maxx, maxy = huc12.bounds['minx'][0], huc12.bounds['miny'][0], huc12.bounds['maxx'][0], huc12.bounds['maxy'][0]
        
        url = 'https://portal.opentopography.org/API/usgsdem'
        params = {
            'datasetName': 'USGS10m',
            'south': miny,
            'north': maxy,
            'west': minx,
            'east': maxx,
            'outputFormat': 'GTiff',
            #'API_Key': Enter the key from opentopography 
        }
        headers = {
            'accept': '*/*'
        }
        
        # Directory to save the downloaded DEMs
        output_DEM_dir = fr'{base_dir}\HUC12_one meter_DEM\{huc}'
        if not os.path.exists(output_DEM_dir):
            os.makedirs(output_DEM_dir)
        
        # Function to download DEM
        def download_dem(west, east, filename):
            for attempt in range(3):
                params.update({'south': miny, 'north': maxy, 'west': west, 'east': east})
                response = requests.get(url, params=params, headers=headers)
                
                if response.status_code == 200:
                    file_path = f'{output_DEM_dir}/{filename}.tiff'
                    with open(file_path, 'wb') as f:
                        f.write(response.content)
                    print(f'File {filename} downloaded successfully and saved to {file_path}.')
                    return file_path
                elif response.status_code == 400:
                    print(f"400 Bad Request for {filename}. Splitting the bounding box and retrying.")
                    return None
                else:
                    print(f"Attempt {attempt + 1}: Failed to retrieve data - Status code: {response.status_code}")
                    if attempt < 2:
                        time.sleep(5)  # Wait for 5 seconds before retrying
                    else:
                        print(f"Failed to download {filename} after 3 attempts.")
                        return None
        
        # First attempt to download the DEM
        file_path = download_dem(minx, maxx, f'{huc}')
        
        # If 400 error occurs, download two DEMs by splitting the bounding box
        if file_path is None:
            midx = (minx + maxx) / 2
            file1 = download_dem(minx, midx+((maxx-minx)*0.1), f'{huc}_west')
            fileone= True
            file2 = download_dem(midx-((maxx-minx)*0.1), maxx, f'{huc}_east')
            filetwo= True
            with rasterio.open(file1) as src1, rasterio.open(file2) as src2:
                # Check if both files were downloaded successfully
                if file1 and file2:
    
                    input_files = [file1, file2]
                    
                    # Define output file paths
                    output_mosaic = fr"{base_dir}\HUC12_one meter_DEM\{huc}\{huc}_east_west_mosaic.tiff"
                    reprojected_output = fr"{base_dir}\HUC12_one meter_DEM\{huc}\{huc}_mosaic_reprojected.tiff"

                    # Mosaic the input files
                    vrt_options = gdal.BuildVRTOptions(resampleAlg='nearest')
                    mosaic_vrt = gdal.BuildVRT('mosaic.vrt', input_files, options=vrt_options)

                    # Check if the VRT was created successfully
                    if mosaic_vrt is None:
                        raise ValueError("Failed to create the VRT mosaic.")
                        
                    # Convert the VRT to a GeoTIFF
                    translated = gdal.Translate(output_mosaic, mosaic_vrt)
                    output_mosaic_flag = True
                    if translated is None:
                        raise ValueError("Failed to translate the VRT to a GeoTIFF.")
                    # Reproject the mosaic to the target CRS (NAD_1983_UTM)
                    target_crs = 'EPSG:4326'  # Replace with the correct EPSG code for your UTM zone
                    warp_options = gdal.WarpOptions(dstSRS=target_crs)
                    warped = gdal.Warp(reprojected_output, output_mosaic, options=warp_options)
                    file_path=reprojected_output
                    reproout= True
                    #close
                    warped= None
                    mosaic_vrt=None  
                    translated=None
                else:
                    print("Failed to download one or both of the DEMs, cannot proceed with mosaicing.")
            src1.close()
            src2.close()
#########################################################################################################################################################
        #reproject the temporary tiff from 4326 to 5070
        output_tiff=fr'{base_dir}\HUC12_one meter_DEM\{huc}\{huc}_5070.tiff'
        
        # Define source and target CRS
        src_crs = CRS.from_epsg(4326)  # Original CRS (EPSG:4326)
        dst_crs = CRS.from_epsg(5070)  # Target CRS (EPSG:5070)
        
        # Open the source raster
        with rasterio.open(file_path) as src:
            transform, width, height = calculate_default_transform(
                src.crs, dst_crs, src.width, src.height, *src.bounds)
            kwargs = src.meta.copy()
            kwargs.update({
                'crs': dst_crs,
                'transform': transform,
                'width': width,
                'height': height
            })
        
            # Reproject and save to the output file
            with rasterio.open(output_tiff, 'w', **kwargs) as dst:
                for i in range(1, src.count + 1):
                    reproject(
                        source=rasterio.band(src, i),
                        destination=rasterio.band(dst, i),
                        src_transform=src.transform,
                        src_crs=src.crs,
                        dst_transform=transform,
                        dst_crs=dst_crs,
                        resampling=Resampling.nearest
                    )
#########################################################################################################################################################
        # Clip and save the final reprojected DEM
        clipped_tiff_dir = fr'{base_dir}\HUC12_one meter_DEM\{huc}'
        huc12 = huc12.to_crs(epsg=5070)
        # Path file
        clipped_tiff = os.path.join(clipped_tiff_dir, f'{huc}_DEM.tiff')
    
        # Convert the HUC12 boundary to GeoJSON-like format
        huc12_geom = [feature["geometry"] for feature in huc12.__geo_interface__["features"]]
    
        # Open the reprojected TIFF file and clip it using the HUC12 boundary
        with rasterio.open(output_tiff) as src:
            out_image, out_transform = mask(src, huc12_geom, crop=True)
            out_image[out_image == src.nodata] = -99999  # Set NoData value
            out_meta = src.meta.copy()
            out_meta.update({
                "driver": "GTiff",
                "height": out_image.shape[1],
                "width": out_image.shape[2],
                "transform": out_transform,
                "crs": src.crs,
                "nodata": -99999
            })
    
            # Save the clipped DEM to a new file
            with rasterio.open(clipped_tiff, 'w', **out_meta) as dst:
                dst.write(out_image)
        src.close()
#########################################################################################################################################################
        #Remove other files
        if fileone: 
            fileone= False
            try:
                os.remove(file1)
                print(f"{file1} removed successfully.")
            except FileNotFoundError:
                print(f"{file1} does not exist.") 
                
        if filetwo: 
            filetwo= False
            try:
                os.remove(file2)
                print(f"{file2} removed successfully.")
            except FileNotFoundError:
                print(f"{file2} does not exist.")   
            del file2
                
        file=f'{output_DEM_dir}\\{huc}.tiff'
        if  os.path.exists(file):
            try:
                os.remove(file)
                print(f"{file} removed successfully.")
            except FileNotFoundError:
                print(f"{file} does not exist.")  
            del file
        
        try:
            os.remove(output_tiff)
            print(f"{output_tiff} removed successfully.")
        except FileNotFoundError:
            print(f"{output_tiff} does not exist.")  
            del output_tiff

        if reproout:
            reproout=False
            try:
                os.remove(reprojected_output)
                print(f"{reprojected_output} removed successfully.")
            except FileNotFoundError:
                print(f"{reprojected_output} does not exist.")  
            del reprojected_output

        if output_mosaic_flag:
            output_mosaic_flag=False
            try:
                os.remove(output_mosaic)
                print(f"{output_mosaic} removed successfully.")
            except FileNotFoundError:
                print(f"{output_mosaic} does not exist.")  
            del output_mosaic
#########################################################################################################################################################
    except Exception as e:
        print(f"Failed to analyse HUC {huc}. Error: {e}")
# Out:
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\050100020104\050100020104_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041201010101\041201010101_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020302020202\020302020202_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020302020205\020302020205_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020302020207\020302020207_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020302020303\020302020303_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020302020304\020302020304_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020302020402\020302020402_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020302020406\020302020406_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020302020605\020302020605_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\011000060401\011000060401_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\011000060402\011000060402_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\011000050501\011000050501_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\011000060403\011000060403_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\011000050504\011000050504_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020301040201\020301040201_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020301040204\020301040204_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020301020203\020301020203_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020301010302\020301010302_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020301020201\020301020201_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020302010201\020302010201_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020302010202\020302010202_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020302010203\020302010203_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020302010302\020302010302_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020301040501\020301040501_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\050100020404\050100020404_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\050100020407\050100020407_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\050100020503\050100020503_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\050100011102\050100011102_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\050100011202\050100011202_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\050100011204\050100011204_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\050100040101\050100040101_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\050100040303\050100040303_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\050100010705\050100010705_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\050100011002\050100011002_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\050100010805\050100010805_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\050100010605\050100010605_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\050100010501\050100010501_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\050100010403\050100010403_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\050100010405\050100010405_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\050100040301\050100040301_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\050100010205\050100010205_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\050100010207\050100010207_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\050100020105\050100020105_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\050100010505\050100010505_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\050100010504\050100010504_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\050100020102\050100020102_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\050100010703\050100010703_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\050100020206\050100020206_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\050100020203\050100020203_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\050100020207\050100020207_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\050100020303\050100020303_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\050100020401\050100020401_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401020104\020401020104_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401010301\020401010301_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401010304\020401010304_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401020306\020401020306_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401020403\020401020403_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401020405\020401020405_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401020506\020401020506_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401040102\020401040102_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401040104\020401040104_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401040201\020401040201_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401040303\020401040303_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401040305\020401040305_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401040307\020401040307_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401010207\020401010207_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401040308\020401040308_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401010305\020401010305_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401040504\020401040504_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401010102\020401010102_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401010106\020401010106_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401010103\020401010103_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401010104\020401010104_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401010105\020401010105_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401010201\020401010201_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401010202\020401010202_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401010204\020401010204_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200040311\020200040311_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200040704\020200040704_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200040706\020200040706_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200040901\020200040901_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200041004\020200041004_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200041005\020200041005_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200041106\020200041106_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200041107\020200041107_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200030102\020200030102_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200030206\020200030206_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200070603\020200070603_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200070604\020200070604_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200070605\020200070605_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200080106\020200080106_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200040906\020200040906_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200040907\020200040907_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200040908\020200040908_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200050205\020200050205_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200030704\020200030704_DEM.tiff already exists. Skipping...
# 020200050403
# HUC number: 020200050403, Percent of remaining files: 92.06%
# File 020200050403 downloaded successfully and saved to D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200050403/020200050403.tiff.
# D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200050403\020200050403.tiff removed successfully.
# D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200050403\020200050403_5070.tiff removed successfully.
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200030804\020200030804_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200060402\020200060402_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200050503\020200050503_DEM.tiff already exists. Skipping...
# 020200050604
# HUC number: 020200050604, Percent of remaining files: 91.73%
# File 020200050604 downloaded successfully and saved to D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200050604/020200050604.tiff.
# D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200050604\020200050604.tiff removed successfully.
# D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200050604\020200050604_5070.tiff removed successfully.
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200060204\020200060204_DEM.tiff already exists. Skipping...
# 020200060403
# HUC number: 020200060403, Percent of remaining files: 91.57%
# File 020200060403 downloaded successfully and saved to D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200060403/020200060403.tiff.
# D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200060403\020200060403.tiff removed successfully.
# D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200060403\020200060403_5070.tiff removed successfully.
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200060505\020200060505_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200060703\020200060703_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200060802\020200060802_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200020302\020200020302_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200061105\020200061105_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200070303\020200070303_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200070304\020200070304_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200060905\020200060905_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200070301\020200070301_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200070302\020200070302_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200070404\020200070404_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200070502\020200070502_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200070503\020200070503_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200080301\020200080301_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200080404\020200080404_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200080504\020200080504_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200061002\020200061002_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200070201\020200070201_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200070202\020200070202_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200020103\020200020103_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200
DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402011611\041402011611_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402020202\041402020202_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402020804\041402020804_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402020503\041402020503_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402020404\041402020404_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402020502\041402020502_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402020504\041402020504_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402020602\041402020602_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402020603\041402020603_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402020605\041402020605_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402020606\041402020606_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402020702\041402020702_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402020703\041402020703_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402020704\041402020704_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402020705\041402020705_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402020801\041402020801_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402020802\041402020802_DEM.tiff already exists. Skipping...
# 041402020807
# HUC number: 041402020807, Percent of remaining files: 7.21%
# File 041402020807 downloaded successfully and saved to D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402020807/041402020807.tiff.
# D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402020807\041402020807.tiff removed successfully.
# D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402020807\041402020807_5070.tiff removed successfully.
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402020905\041402020905_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402020805\041402020805_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402020806\041402020806_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402020902\041402020902_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402020903\041402020903_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402030102\041402030102_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402030103\041402030103_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402030201\041402030201_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402030204\041402030204_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401010306\020401010306_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401010503\020401010503_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401010504\020401010504_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401010505\020401010505_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401010603\020401010603_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401020101\020401020101_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401020204\020401020204_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401020302\020401020302_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401020303\020401020303_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401020304\020401020304_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401020305\020401020305_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401020402\020401020402_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401020501\020401020501_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401020502\020401020502_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401020503\020401020503_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401040101\020401040101_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401020505\020401020505_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401020507\020401020507_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401040103\020401040103_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401040105\020401040105_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401040106\020401040106_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401040107\020401040107_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401040202\020401040202_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401040203\020401040203_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401040304\020401040304_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020501010102\020501010102_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020501010103\020501010103_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020501010201\020501010201_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402010903\041402010903_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402010904\041402010904_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402011002\041402011002_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402010905\041402010905_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402010906\041402010906_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402011001\041402011001_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402011004\041402011004_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402011005\041402011005_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402011006\041402011006_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402011007\041402011007_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020501010202\020501010202_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\011000050503\011000050503_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\011000050201\011000050201_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\011000050202\011000050202_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\011000050505\011000050505_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200060601\020200060601_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200060603\020200060603_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200040705\020200040705_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402020402\041402020402_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200040202\020200040202_DEM.tiff already exists. Skipping...
# 020200010607
# HUC number: 020200010607, Percent of remaining files: 2.51%
# File 020200010607 downloaded successfully and saved to D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200010607/020200010607.tiff.
# D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200010607\020200010607.tiff removed successfully.
# D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200010607\020200010607_5070.tiff removed successfully.
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020501011205\020501011205_DEM.tiff already exists. Skipping...
# 043001080203
# HUC number: 043001080203, Percent of remaining files: 2.35%
# File 043001080203 downloaded successfully and saved to D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\043001080203/043001080203.tiff.
# D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\043001080203\043001080203.tiff removed successfully.
# D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\043001080203\043001080203_5070.tiff removed successfully.
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200080203\020200080203_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020501020102\020501020102_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402020904\041402020904_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020501020103\020501020103_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\011000050506\011000050506_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020301010105\020301010105_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020501010401\020501010401_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020501011206\020501011206_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020501020301\020501020301_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401010206\020401010206_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200040308\020200040308_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020501011104\020501011104_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020501010101\020501010101_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200040902\020200040902_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402020604\041402020604_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401010205\020401010205_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401010302\020401010302_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402020601\041402020601_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401010303\020401010303_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020501010902\020501010902_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020501020501\020501020501_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020401010101\020401010101_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200080505\020200080505_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\041402020701\041402020701_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020501010601\020501010601_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200040204\020200040204_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020200061001\020200061001_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\011000060405\011000060405_DEM.tiff already exists. Skipping...
# File D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\020301020202\020301020202_DEM.tiff already exists. Skipping...
# CPU times: total: 1min 49s
# Wall time: 18min 32s

# %% [markdown]
# # Visualization

# %%
# %%time
# Select 10 HUCs
selected_hucs = huc12_with_all_layers[:10]

fig, axes = plt.subplots(2, 5, figsize=(25, 10))  # 2 rows, 5 columns

# Define legend elements
legend_elements = [
    plt.Line2D([0], [0], color='gray', lw=2, label='HUC boundary'),
    plt.Line2D([0], [0], color='blue', lw=2, label='Streams'),
    plt.Line2D([0], [0], marker='o', color='red', markersize=10, label='Culverts'),
    plt.Line2D([0], [0], color='orange', lw=1, label='Streets and roads'),
    plt.Line2D([0], [0], color='brown', lw=1.5, linestyle='dashed', label='railroad')
]

for ax, huc in zip(axes.flat, selected_hucs):
    # Define paths
    output_huc12_path = os.path.join(r'D:\culvert repo\Results\Clipped_layers\clipped_huc12', f'{huc}_huc12.shp')
    output_stream_path = os.path.join(r'D:\culvert repo\Results\Clipped_layers\clipped_streams', f'{huc}_streams.shp')
    output_road_path = os.path.join(r'D:\culvert repo\Results\Clipped_layers\clipped_street', f'{huc}_streets.shp')
    output_culvert_path = os.path.join(r'D:\culvert repo\Results\Clipped_layers\clipped_culverts', f'{huc}_culverts.shp')
    clipped_tiff = os.path.join(rf'D:\culvert repo\Results\Clipped_layers\HUC12_one meter_DEM\{huc}', f'{huc}_DEM.tiff')
    output_railroad_path = os.path.join(r'D:\culvert repo\Results\Clipped_layers\clipped_railroad', f'{huc}_railroads.shp')
    
    # Read and plot DEM
    with rasterio.open(clipped_tiff) as dem:
        dem_data = dem.read(1).astype(float)
        dem_data[dem_data == -99999] = np.nan
        dem_bounds = dem.bounds
        # Plot DEM
        im = ax.imshow(dem_data, cmap='gray', extent=(dem_bounds.left, dem_bounds.right, dem_bounds.bottom, dem_bounds.top))
    
    # Overlay shapefiles
    gpd.read_file(output_huc12_path).boundary.plot(ax=ax, edgecolor='gray', linewidth=1.5) # HUC12
    gpd.read_file(output_stream_path).plot(ax=ax, color='blue', linewidth=1) 
    gpd.read_file(output_culvert_path).plot(ax=ax, color='red', markersize=20)
    gpd.read_file(output_road_path).plot(ax=ax, color='orange', linewidth=1)
    if os.path.exists(output_railroad_path):
        gpd.read_file(output_railroad_path).plot(ax=ax, color='brown', linewidth=1.5,linestyle='dashed')
    
    # Add scale bar
    scalebar = ScaleBar(1, units='m', dimension='si-length', location='lower left',
                        length_fraction=0.1, font_properties={'size': 8}, frameon=False)
    ax.add_artist(scalebar)
    
    # Add title
    ax.set_title(f'HUC {huc}', fontsize=12, fontname='Times New Roman')
    
    # Hide axis
    ax.set_axis_off()
    # Add colorbar to each subplot
    cbar = fig.colorbar(im, ax=ax, orientation='vertical')
    cbar.set_label('Elevation (m)')

# Add unified legend
fig.legend(
    handles=legend_elements, loc='lower center', bbox_to_anchor=(0.5, -0.05), ncol=5, prop={'family': 'Times New Roman', 'size': 15},
    markerscale=0.8, frameon=False )

plt.tight_layout(rect=[0, 0, 1, 0.96])  # Adjust layout
plt.savefig(r'D:\culvert repo\Results\Figures\DEM_All_layers_combined_10huc.png', dpi=300, bbox_inches="tight")
plt.show()
# Out:
# CPU times: total: 11min 12s
# Wall time: 11min 47s

# %%
# Date and time
now = datetime.datetime.now()
print(f"Date and time: {now}")
# Out:
# Date and time: 2025-01-30 15:21:08.823642

# %%
# %load_ext watermark
# Print Python version and some dependencies
# %watermark -v -m -p numpy,geopandas,rasterio,osgeo,pyproj,matplotlib,contextily
# Out:
# The watermark extension is already loaded. To reload it, use:
#   %reload_ext watermark
# Python implementation: CPython
# Python version       : 3.12.4
# IPython version      : 8.20.0
#
# numpy     : 2.0.2
# geopandas : 1.0.1
# rasterio  : 1.3.10
# osgeo     : 3.9.2
# pyproj    : 3.6.1
# matplotlib: 3.8.4
# contextily: 1.6.1
#
# Compiler    : MSC v.1940 64 bit (AMD64)
# OS          : Windows
# Release     : 11
# Machine     : AMD64
# Processor   : Intel64 Family 6 Model 183 Stepping 1, GenuineIntel
# CPU cores   : 24
# Architecture: 64bit
